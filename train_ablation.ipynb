# %%
import train_ablation

# %%
train_ablation.run_doorkey_ablation_training()
# Out:
# 🚀 开始消融实验: MiniGrid-DoorKey-5x5-v0
# 📂 数据保存至: ./logs_ablation_doorkey
# ⚙️  总步数: 200000 | 种子: [101, 102, 103]
#
# Training [Baseline] Seed 101...
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 0.105    |
# | time/              |          |
# |    fps             | 2665     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | 0.0558       |
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# ...
