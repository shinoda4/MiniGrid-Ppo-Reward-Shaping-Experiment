# %%
import verify_dqn

# %%
verify_dqn.verify_dqn_setup()
# Out:
# 🔍 正在验证 DQN 与 MiniGrid 的兼容性...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
#    ✅ DQN 模型构建成功 (CNN 维度匹配)
#    ⏳ 尝试运行 200 步训练...
#    ✅ DQN 训练循环测试通过 (Replay Buffer 正常)
#    ✅ 动作预测测试通过 (Action: 1)
