# %%
import plot_killshot

# %%
plot_killshot.plot_killshot()
# Out:
# 📂 正在从 ./logs_killshot_8x8 读取 Kill Shot 数据...
# 📊 正在生成最终 Kill Shot 对比图...
# ✅ 绝杀图已生成！图片保存为: killshot_result_8x8.png
#    预期效果: 红线稳步上升，黄线和黑线在底部变成一条直线 (0.0)
