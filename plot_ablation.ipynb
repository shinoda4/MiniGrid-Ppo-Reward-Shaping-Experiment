# %%
import plot_ablation

# %%
plot_ablation.plot_ablation()
# Out:
# 📂 正在从 ./logs_ablation_doorkey 读取数据...
# 📊 正在生成消融实验对比图...
# /Users/carl/PycharmProjects/MiniGrid-Ppo-Reward-Shaping-Experiment/plot_ablation.py:116: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(
# ✅ 绘图完成！图片已保存为: ablation_result.png

# %%
import plot_ablation_fixed

# %%
plot_ablation_fixed.plot_ablation()
# Out:
# 📂 正在从 ./logs_ablation_doorkey 读取数据...
# 📊 正在生成消融实验对比图 (高平滑度)...
# ✅ 绘图完成！图片已保存为: ablation_result_optimized.png
