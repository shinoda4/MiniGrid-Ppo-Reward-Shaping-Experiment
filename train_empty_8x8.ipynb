# %%
import train

# %%
train.run_empty_8x8_v0_training()
# Out:
# --- 开始实验: MiniGrid-Empty-8x8-v0 ---
# 数据将保存至: ./logs_paper_minigrid_empty_8x8_v0
#
# [Baseline] Training Seed 101...
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 0.0758   |
# | time/              |          |
# |    fps             | 2839     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | 0.0813       |
# | time/                   |              |
# |    fps                  | 1150         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# ...
