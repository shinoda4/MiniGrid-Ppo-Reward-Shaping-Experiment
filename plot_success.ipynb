# %%
import plot_success

# %%
plot_success.plot_success()
# Out:
# 📂 正在从 ./logs_ablation_doorkey 读取数据计算成功率...
# 📊 正在生成成功率 (Success Rate) 对比图...
# /Users/carl/PycharmProjects/MiniGrid-Ppo-Reward-Shaping-Experiment/plot_success.py:196: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])
# ✅ 成功率图表已生成！图片保存为: success_rate_5x5.png

# %%
plot_success.plot_success_8x8()
# Out:
# 📂 正在从 ./logs_killshot_8x8 读取数据计算成功率...
# 📊 正在生成成功率 (Success Rate) 对比图...
# /Users/carl/PycharmProjects/MiniGrid-Ppo-Reward-Shaping-Experiment/plot_success.py:268: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])
# ✅ 成功率图表已生成！图片保存为: success_rate_8x8.png
