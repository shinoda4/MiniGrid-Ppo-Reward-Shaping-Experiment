# %%
import train_dqn_generality

# %%
train_dqn_generality.run_dqn_generality()
# Out:
# 🔥 开始通用性验证实验 (DQN): MiniGrid-DoorKey-8x8
# 📂 数据保存至: ./logs_generality_dqn_8x8
#
# 🚀 Training [DQN_Baseline] Seed 201...
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 640      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1202     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2560     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.87e-09 |
# |    n_updates        | 389      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 640      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 8        |
# ...
