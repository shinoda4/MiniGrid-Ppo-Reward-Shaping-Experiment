# %%
import plot_empty

# %%
plot_empty.plot_empty()
# Out:
# 正在加载数据并绘图...
# ✅ 绘图完成！图片已保存为 logs_paper_minigrid_empty_8x8_v0.png

# %%
import reasonable_plot_results

# %%
reasonable_plot_results.plot_paper_figure()
# Out:
# 正在读取数据，假设环境 MAX_STEPS = 256 ...
# ✅ 绘图完成！
# 图片已保存为: logs_paper_minigrid_empty_8x8_v0_fixed.png
# 注意：该图使用了基于步数重构的奖励，剔除了 Potential Shaping 的数值影响，范围应在 [0, 1] 之间。

# %%
import plot_doorkey

# %%
plot_doorkey.plot_doorkey()
# Out:
# 正在读取 ./logs_paper_minigrid_doorkey_5x5_v0 下的数据...
# ✅ DoorKey 实验图已生成！
