# %%
import verify_8x8_setup

# %%
verify_8x8_setup.verify_8x8_logic()
# Out:
# 🔍 正在初始化 MiniGrid-DoorKey-8x8-v0 进行逻辑验证...
#    地图尺寸: 8x8
#    钥匙位置: [1 3]
#    终点位置: [6 6]
#
# --- 测试场景: 站在钥匙上 (未捡起) ---
#    Simple Potential: 0.5000 (只看终点距离)
#    Ours Potential:   1.0000 (Stage 0: 满分接近 1.0)
#
# --- 测试场景: 捡起钥匙瞬间 ---
#    Simple Potential: 0.5000 (应该没变化，因为位置没变)
#    Ours Potential:   1.8125 (应该暴涨! Jump into Stage 1, > 1.0)
#
# ✅ 验证通过！8x8 环境下，Hierarchical Shaping 逻辑正常，Simple Shaping 逻辑正常。
#    Ours 成功捕捉到了‘捡起钥匙’的价值，而 Simple 对此无动于衷。

# %%
import train_killshot_8x8

# %%
train_killshot_8x8.run_killshot_training()
# Out:
# 🔥 开始 Kill Shot 实验: MiniGrid-DoorKey-8x8-v0
# 📂 数据保存至: ./logs_killshot_8x8
# ⚙️  总步数: 500000 (加大力度!)
#
# 🚀 Training [Baseline] Seed 101...
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 567      |
# |    ep_rew_mean     | 0.136    |
# | time/              |          |
# |    fps             | 2614     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | 0.0678       |
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# ...
