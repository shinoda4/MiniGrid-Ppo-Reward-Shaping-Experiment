# %%
import train

# %%
train.run_doorkey_5x5_v0_training()
# Out:
# --- 开始实验: MiniGrid-DoorKey-5x5-v0 ---
# 数据将保存至: ./logs_paper_minigrid_doorkey_5x5_v0
#
# [Baseline] Training Seed 101 (Shaping=False)...
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 0.105    |
# | time/              |          |
# |    fps             | 2939     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 223         |
# |    ep_rew_mean          | 0.12        |
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# ...
