# %%
import train_dqn_generality_5x5

# %%
train_dqn_generality_5x5.run_dqn_generality()
# Out:
# 🔥 开始通用性验证实验 (DQN): MiniGrid-DoorKey-5x5
# 📂 数据保存至: ./logs_generality_dqn_5x5
#
# 🚀 Training [DQN_Baseline] Seed 201...
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 250      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 9675     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 250      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1504     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# ...
