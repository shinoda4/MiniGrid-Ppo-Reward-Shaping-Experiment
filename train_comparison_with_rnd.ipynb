# %%
import train_comparison_with_rnd

# %%
train_comparison_with_rnd.run_comparison_training()
# Out:
# 🔥 开始最终对比实验 (含 RND): MiniGrid-DoorKey-8x8
# 📂 数据保存至: ./logs_comparison_rnd_8x8
#
# 🚀 Training [Baseline] Seed 101...
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 567      |
# |    ep_rew_mean     | 0.136    |
# | time/              |          |
# |    fps             | 2683     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | 0.0678       |
# | time/                   |              |
# |    fps                  | 1095         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# ...
